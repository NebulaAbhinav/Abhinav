# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows",1000)
import matplotlib.pyplot as plt
from datetime import date, timedelta 
import yfinance as yf 
from yahoo_fin import stock_info as si
import time



def main():


   #spdow = ['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AFL', 'AGN', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'ALL', 'ALLE', 'ALXN', 'AMAT', 'AMCR', 'AMD', 'AME', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANET', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APD', 'APH', 'APTV', 'ARE', 'ARNC', 'ATO', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AZO', 'BA', 'BAC', 'BAX', 'BBY', 'BDX', 'BEN', 'BF.B', 'BIIB', 'BK', 'BKNG', 'BKR', 'BLK', 'BLL', 'BMY', 'BR', 'BRK.B', 'BSX', 'BWA', 'BXP', 'C', 'CAG', 'CAH', 'CAT', 'CB', 'CBOE', 'CBRE', 'CCI', 'CCL', 'CDNS', 'CDW', 'CE', 'CERN', 'CF', 'CFG', 'CHD', 'CHRW', 'CHTR', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COO', 'COP', 'COST', 'COTY', 'CPB', 'CPRI', 'CPRT', 'CRM', 'CSCO', 'CSX', 'CTAS', 'CTL', 'CTSH', 'CTVA', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE', 'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISCK', 'DISH', 'DLR', 'DLTR', 'DOV', 'DOW', 'DRE', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'DXC', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR', 'EOG', 'EQIX', 'EQR', 'ES', 'ESS', 'ETFC', 'ETN', 'ETR', 'EVRG', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FANG', 'FAST', 'FB', 'FBHS', 'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FLIR', 'FLS', 'FLT', 'FMC', 'FOX', 'FOXA', 'FRC', 'FRT', 'FTI', 'FTNT', 'FTV', 'GD', 'GE', 'GILD', 'GIS', 'GL', 'GLW', 'GM', 'GOOG', 'GOOGL', 'GPC', 'GPN', 'GPS', 'GRMN', 'GS', 'GWW', 'HAL', 'HAS', 'HBAN', 'HBI', 'HCA', 'HD', 'HES', 'HFC', 'HIG', 'HII', 'HLT', 'HOG', 'HOLX', 'HON', 'HP', 'HPE', 'HPQ', 'HRB', 'HRL', 'HSIC', 'HST', 'HSY', 'HUM', 'IBM', 'ICE', 'IDXX', 'IEX', 'IFF', 'ILMN', 'INCY', 'INFO', 'INTC', 'INTU', 'IP', 'IPG', 'IPGP', 'IQV', 'IR', 'IRM', 'ISRG', 'IT', 'ITW', 'IVZ', 'J', 'JBHT', 'JCI', 'JKHY', 'JNJ', 'JNPR', 'JPM', 'JWN', 'K', 'KEY', 'KEYS', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KMX', 'KO', 'KR', 'KSS', 'KSU', 'L', 'LB', 'LDOS', 'LEG', 'LEN', 'LH', 'LHX', 'LIN', 'LKQ', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX', 'LUV', 'LVS', 'LW', 'LYB', 'LYV', 'M', 'MA', 'MAA', 'MAR', 'MAS', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MGM', 'MHK', 'MKC', 'MKTX', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MOS', 'MPC', 'MRK', 'MRO', 'MS', 'MSCI', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MXIM', 'MYL', 'NBL', 'NCLH', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NI', 'NKE', 'NLOK', 'NLSN', 'NOC', 'NOV', 'NOW', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NVR', 'NWL', 'NWS', 'NWSA', 'O', 'ODFL', 'OKE', 'OMC', 'ORCL', 'ORLY', 'OXY', 'PAYX', 'PBCT', 'PCAR', 'PEAK', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'PPG', 'PPL', 'PRGO', 'PRU', 'PSA', 'PSX', 'PVH', 'PWR', 'PXD', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'RE', 'REG', 'REGN', 'RF', 'RHI', 'RJF', 'RL', 'RMD', 'ROK', 'ROL', 'ROP', 'ROST', 'RSG', 'RTN', 'SBAC', 'SBUX', 'SCHW', 'SEE', 'SHW', 'SIVB', 'SJM', 'SLB', 'SLG', 'SNA', 'SNPS', 'SO', 'SPG', 'SPGI', 'SRE', 'STE', 'STT', 'STX', 'STZ', 'SWK', 'SWKS', 'SYF', 'SYK', 'SYY', 'T', 'TAP', 'TDG', 'TEL', 'TFC', 'TFX', 'TGT', 'TIF', 'TJX', 'TMO', 'TMUS', 'TPR', 'TROW', 'TRV', 'TSCO', 'TSN', 'TTWO', 'TWTR', 'TXN', 'TXT', 'UA', 'UAA', 'UAL', 'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URI', 'USB', 'UTX', 'V', 'VAR', 'VFC', 'VIAC', 'VLO', 'VMC', 'VNO', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VZ', 'WAB', 'WAT', 'WBA', 'WCG', 'WDC', 'WEC', 'WELL', 'WFC', 'WHR', 'WLTW', 'WM', 'WMB', 'WMT', 'WRB', 'WRK', 'WU', 'WY', 'WYNN', 'XEC', 'XEL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'XYL', 'YUM', 'ZBH', 'ZBRA', 'ZION', 'ZTS']
   spdow = ['AAPL','AMD','ADBE']
   for stck in spdow:
        #Live value
        global buydata
        global seldata
        live = si.get_live_price(stck)

        today = date.today()
        first = date.today() - timedelta(600)
        ###############################
        today = today.strftime("%Y-%m-%d")

        first = first.strftime("%Y-%m-%d")

        data = yf.download(stck,first,today) #Date is already index

        #MAverage last 15 days 
        dmodel = data.reset_index()
        mclose = dmodel['Close']
        fmclose = []
        for i in range(len(mclose)):
            fmclose.append(mclose[i])
        fmclose.append(live)
        z = [] 
        #########################################
        for i in range(15):
            z.append(i+1)
        d15 = pd.DataFrame({"Value":z})
        d15['Close'] = fmclose[-15:] 
        d15['ma15'] = d15.iloc[:,1].mean()
        ma15 = d15['ma15'].values[-1]



        #MAverage last 30 days 
        #########################################
        w= []
        for i in range(30):
            w.append(i+1)
        d30 = pd.DataFrame({"Value":w})
        d30['Close'] = fmclose[-30:] 
        d30['ma30'] = d30.iloc[:,1].mean()
        ma30 = d30['ma30'].values[-1]



        #MAverage last 60 days 
        #########################################
        q= []
        for i in range(60):
            q.append(i+1)
        d60 = pd.DataFrame({"Value":q})
        d60['Close'] = fmclose[-60:] 
        d60['ma60'] = d60.iloc[:,1].mean()
        ma60 = d60['ma60'].values[-1]



        #MAverage last 365 days 
        #########################################
        e= []
        for i in range(365):
            e.append(i+1)
        d365 = pd.DataFrame({"Value":e})
        d365['Close'] = fmclose[-365:] 
        d365['ma365'] = d365.iloc[:,1].mean()
        ma365 = d365['ma365'].values[-1]



        # ma15, ma30, ma60, ma365

        dmatrix = []

        # 1. Increasing in 15 days range
        if (ma15 > fmclose[-15]):
            dmatrix.append("buy")

        # 2. 15 day average > 30 days average 
        if (ma15 > ma30):
            dmatrix.append("buy")

        # 3. 30 days Increase > =10%
        if ( ((ma30 - fmclose[-30])/fmclose[-30])>= 0.08 ):
            dmatrix.append("buy")

        # 4. 60 days Increase > = 12%
        if ( ((ma60 - fmclose[-60])/fmclose[-60])>= 0.15):
            dmatrix.append("buy")
        # 5. 365 days increase > = 20%
        if ( ((ma365 - fmclose[-365])/fmclose[-365])>= 0.25 ):
            dmatrix.append("buy")

        print(dmatrix.count("buy"))

        status = "" 
        if (dmatrix.count("buy") >=3):
            status = "buy"
        else :
            status = "no buy"



        #if matches criteria------------------>
        #1. name, buy time, Buy value 
        #2. Check if name exists in json file -->
            #write current Price, gain percentage, gain price 

        #if criteria doesn't meet---------------->
        #1. Check for name--->
            #a. if exists --> 1. make transaction entry in different file (get data from other file ).
                             #2. Remove entry from current file.   


        buydata = pd.read_csv("bdata.csv")

        #delete

        #Check if buy data has given name -->
        bname = stck #(Give name)
        bdate = date.today()
        bprice = live
        bcprice = live

        #########################################################################
        #if len(buydata == 0):
        buyindex = []
        statuscheck =""
        if (len(buydata) == 0 and status == "buy"):
            bgain= (bcprice - bprice)
            bgpercent= (bgain/bprice)*100
            buydata= buydata.append({'Name':bname, 'Buydate':bdate, 'Buyprice':bprice,'Currentprice':bcprice,"Gain%":bgpercent,"Gainprice":bgain} , ignore_index=True)

        for i in range(len(buydata)):
            if (status == "buy" and buydata['Name'][i] == bname):
                buyindex.append(i)
                statuscheck = "1"
                break
            elif (status == "buy" and buydata['Name'][i] != bname):
                statuscheck = "2"


        if (statuscheck =="1"):
            bgain= (bcprice - buydata['Buyprice'][buyindex[0]])
            bgpercent= (bgain/buydata['Buyprice'][buyindex[0]])*100
            buydata['Currentprice'][buyindex[0]] = bcprice;
            buydata["Gainprice"][buyindex[0]] = bgain;
            buydata["Gain%"][buyindex[0]] = bgpercent;
        #fresh criteria match -->
        elif (statuscheck =="2"):
            bgain= (bcprice - bprice)
            bgpercent= (bgain/bprice)*100
            buydata= buydata.append({'Name':bname, 'Buydate':bdate, 'Buyprice':bprice,'Currentprice':bcprice,"Gain%":bgpercent,"Gainprice":bgain} , ignore_index=True)



        seldata = pd.read_csv("sdata.csv")



        # For nobuy status -->
        #1. Check if status is "no buy"
        selindex = []
        sellstatus = ""
        for i in range(len(buydata)):
            if (status == "no buy" and buydata['Name'][i] == bname):
                selindex.append(i)
                sellstatus = "yes"
                break

        if (sellstatus == "yes"):
            #1. Add entry in seldata -->
            seldata= seldata.append({'Name':bname, 'Buydate':buydata['Buydate'][selindex[0]], 'Buyprice':buydata['Buyprice'][selindex[0]],'Currentprice':buydata['Currentprice'][selindex[0]],"Gain%":buydata['Gain%'][selindex[0]],"Gainprice":buydata['Gainprice'][selindex[0]]} , ignore_index=True)
            #2. Remove entry in buydata
            buydata = buydata.drop(selindex[0])

        buydata.to_csv('bdata.csv',index = False)
        seldata.to_csv('sdata.csv',index = False)
        #print("Buy data ------>")
        #print(buydata)
        #print()
        #print("Sell data ------->")
        #print(seldata)
        #print()
        #print()
    #   delete
        #print("_______________________________________________________________________________________________________________________________________________________________")




#Run program continously after 15 sec  --------->
while True:
    main()
    print("Buy data ------>")
    print(buydata)
    print()
    print("Sell data ------->")
    print(seldata)
    print()
    print()
 #   delete
    print("_______________________________________________________________________________________________________________________________________________________________")
    time.sleep(10)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 3
# [*********************100%***********************]  1 of 1 completed
# 2
# [*********************100%***********************]  1 of 1 completed
# 2
# Buy data ------>
#    Name     Buydate    Buyprice  Currentprice     Gain%  Gainprice  \
# 0  tsla  2020-03-02  725.500000    732.250000  0.930393       6.75
# 1  AAPL  2020-05-23  318.890015    318.890015  0.000000       0.00
#
#       Sell_at  Difference
# 0  705.971217   26.278783
# 1         NaN         NaN
#
# Sell data ------->
#     Name    Buydate    Buyprice  Currentprice      Gain%  Gainprice
# 0     PG  2/13/2020  123.449997    125.430000   1.603891   1.980003
# 1   INTC  2/15/2020   67.353600     66.599998  -1.118873  -0.753601
# 2   AAPL   2/4/2020  307.410004    315.237000   2.546110   7.826996
# 3     KO   2/8/2020   59.221699     59.955002   1.238234   0.733303
# 4    NKE  2/20/2020  102.815002     99.940002  -2.796284  -2.875000
# ...
