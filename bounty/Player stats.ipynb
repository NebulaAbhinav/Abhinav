# %%
################################################################################################################################
#epl_player stats 
################################################################################################################################
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
pd.set_option("display.max_rows",1000)
url = "https://scores.nbcsports.com/epl/player_leaders.asp" #url
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')


############
#find all tables with same class
############

alltables = []
for my_tag in soup.find_all(class_="shsTable shsBorderTable"):
    alltables.append(str(my_tag).split('</table>')) 

firsttable = []    
for i in alltables[0]:
    firsttable.append(i)

secondtable = []
for i in alltables[1]:
    secondtable.append(i)

thirdtable = []
for i in alltables[2]:
    thirdtable.append(i) 

fourthtable = []
for i in alltables[3]:
    fourthtable.append(i)

fifthtable = []
for i in alltables[2]:
    fifthtable.append(i)

sixthtable = []
for i in alltables[2]:
    sixthtable.append(i)


#############
#Extract all table -1
#############
table1 = BeautifulSoup(firsttable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("epl_Top_Goal_Scorers.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -2
#############
table1 = BeautifulSoup(secondtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("epl_Yellow_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -3
#############
table1 = BeautifulSoup(thirdtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("epl_Red_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -4
#############
table1 = BeautifulSoup(fourthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("epl_Penalty_Kick_Goals.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 5
#############
table1 = BeautifulSoup(fifthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("epl_Goals_Against.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 6
#############
table1 = BeautifulSoup(sixthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("epl_Clean_Sheets.txt","w+")
f.write(text)
f.close()

################################################################################################################################
#laliga_player stats 
################################################################################################################################

from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
pd.set_option("display.max_rows",1000)
url = "http://scores.nbcsports.com/liga/player_leaders.asp" #url
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')


############
#find all tables with same class
############

alltables = []
for my_tag in soup.find_all(class_="shsTable shsBorderTable"):
    alltables.append(str(my_tag).split('</table>')) 

firsttable = []    
for i in alltables[0]:
    firsttable.append(i)

secondtable = []
for i in alltables[1]:
    secondtable.append(i)

thirdtable = []
for i in alltables[2]:
    thirdtable.append(i) 

fourthtable = []
for i in alltables[3]:
    fourthtable.append(i)

fifthtable = []
for i in alltables[2]:
    fifthtable.append(i)

sixthtable = []
for i in alltables[2]:
    sixthtable.append(i)


#############
#Extract all table -1
#############
table1 = BeautifulSoup(firsttable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("laliga_Top_Goal_Scorers.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -2
#############
table1 = BeautifulSoup(secondtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("laliga_Yellow_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -3
#############
table1 = BeautifulSoup(thirdtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("laliga_Red_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -4
#############
table1 = BeautifulSoup(fourthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("laliga_Penalty_Kick_Goals.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 5
#############
table1 = BeautifulSoup(fifthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("laliga_Goals_Against.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 6
#############
table1 = BeautifulSoup(sixthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("laliga_Clean_Sheets.txt","w+")
f.write(text)
f.close()

################################################################################################################################
#ligue1_player stats 
################################################################################################################################
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
pd.set_option("display.max_rows",1000)
url = "http://scores.nbcsports.com/fran/player_leaders.asp" #url
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')


############
#find all tables with same class
############

alltables = []
for my_tag in soup.find_all(class_="shsTable shsBorderTable"):
    alltables.append(str(my_tag).split('</table>')) 

firsttable = []    
for i in alltables[0]:
    firsttable.append(i)

secondtable = []
for i in alltables[1]:
    secondtable.append(i)

thirdtable = []
for i in alltables[2]:
    thirdtable.append(i) 

fourthtable = []
for i in alltables[3]:
    fourthtable.append(i)

fifthtable = []
for i in alltables[2]:
    fifthtable.append(i)

sixthtable = []
for i in alltables[2]:
    sixthtable.append(i)


#############
#Extract all table -1
#############
table1 = BeautifulSoup(firsttable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("ligue1_Top_Goal_Scorers.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -2
#############
table1 = BeautifulSoup(secondtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("ligue1_Yellow_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -3
#############
table1 = BeautifulSoup(thirdtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("ligue1_Red_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -4
#############
table1 = BeautifulSoup(fourthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("ligue1_Penalty_Kick_Goals.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 5
#############
table1 = BeautifulSoup(fifthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("ligue1_Goals_Against.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 6
#############
table1 = BeautifulSoup(sixthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("ligue1_Clean_Sheets.txt","w+")
f.write(text)
f.close()

################################################################################################################################
#bungesliga_player stats 
################################################################################################################################
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
pd.set_option("display.max_rows",1000)
url = "http://scores.nbcsports.com/bund/player_leaders.asp" #url
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')


############
#find all tables with same class
############

alltables = []
for my_tag in soup.find_all(class_="shsTable shsBorderTable"):
    alltables.append(str(my_tag).split('</table>')) 

firsttable = []    
for i in alltables[0]:
    firsttable.append(i)

secondtable = []
for i in alltables[1]:
    secondtable.append(i)

thirdtable = []
for i in alltables[2]:
    thirdtable.append(i) 

fourthtable = []
for i in alltables[3]:
    fourthtable.append(i)

fifthtable = []
for i in alltables[2]:
    fifthtable.append(i)

sixthtable = []
for i in alltables[2]:
    sixthtable.append(i)


#############
#Extract all table -1
#############
table1 = BeautifulSoup(firsttable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("bliga_Top_Goal_Scorers.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -2
#############
table1 = BeautifulSoup(secondtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("bliga_Yellow_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -3
#############
table1 = BeautifulSoup(thirdtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("bliga_Red_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -4
#############
table1 = BeautifulSoup(fourthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("bliga_Penalty_Kick_Goals.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 5
#############
table1 = BeautifulSoup(fifthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("bliga_Goals_Against.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 6
#############
table1 = BeautifulSoup(sixthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("bliga_Clean_Sheets.txt","w+")
f.write(text)
f.close()

################################################################################################################################
#serieA_player stats 
################################################################################################################################
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
pd.set_option("display.max_rows",1000)
url = "http://scores.nbcsports.com/seri/player_leaders.asp" #url
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')


############
#find all tables with same class
############

alltables = []
for my_tag in soup.find_all(class_="shsTable shsBorderTable"):
    alltables.append(str(my_tag).split('</table>')) 

firsttable = []    
for i in alltables[0]:
    firsttable.append(i)

secondtable = []
for i in alltables[1]:
    secondtable.append(i)

thirdtable = []
for i in alltables[2]:
    thirdtable.append(i) 

fourthtable = []
for i in alltables[3]:
    fourthtable.append(i)

fifthtable = []
for i in alltables[2]:
    fifthtable.append(i)

sixthtable = []
for i in alltables[2]:
    sixthtable.append(i)


#############
#Extract all table -1
#############
table1 = BeautifulSoup(firsttable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("serieA_Top_Goal_Scorers.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -2
#############
table1 = BeautifulSoup(secondtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("serieA_Yellow_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -3
#############
table1 = BeautifulSoup(thirdtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("serieA_Red_card.txt","w+")
f.write(text)
f.close()


#############
#Extract all table -4
#############
table1 = BeautifulSoup(fourthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("serieA_Penalty_Kick_Goals.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 5
#############
table1 = BeautifulSoup(fifthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("serieA_Goals_Against.txt","w+")
f.write(text)
f.close()

#############
#Extract all table - 6
#############
table1 = BeautifulSoup(sixthtable[0], 'html.parser')


rowcell = []#all rows
for row in table1.find_all('tr'):
    for cell in table1.find_all('td'):
        c = cell.text.replace('\n','')
        rowcell.append(c)
    break

print(rowcell)
#find all column names
tcol = ['Pos', 'Name', 'Total']#column names 



tcol = tcol[:11] ###########################change according to the number of columns 
print(tcol)

#remove row cells
rindex = [0,1,2,3,34]

rowcell = np.delete(rowcell, rindex)
print(len(rowcell))
        
#make rowcell 2DD
rowcell = np.array(rowcell)
r = int(len(rowcell)/len(tcol))

c = int(len(tcol))
print(c)
rowcell = np.reshape(rowcell,(r,c))

#Making dataframe
from IPython.display import HTML
table= pd.DataFrame(rowcell, columns = tcol)
table = table.rename_axis(None)
q = table.to_html(classes='table table-hover table-bordered', index=False)

text = """<html><style type="text/css">

table, th, td {
border: 2px #2b2b2b solid;
color: #2b2b2b;
}

table { background-color: white; }
th { background-color: silver; }

</style>
<font color="black">""" + q + "</font></body></html>"
#Write in text file
f= open("serieA_Clean_Sheets.txt","w+")
f.write(text)
f.close()
# Out:
# ['Top Goal Scorers', 'Pos', 'Name', 'Total', '1 ', 'J. Vardy', '17', '2 ', 'M. Rashford', '14', '2 ', 'D. Ings', '14', '2 ', 'P. Aubameyang', '14', '5 ', 'T. Abraham', '13', '6 ', 'S. Mané', '11', '6 ', 'H. Kane', '11', '6 ', 'R. Sterling', '11', '9 ', 'M. Salah', '10', '9 ', 'S. Agüero', '10', 'More Stats']
# ['Pos', 'Name', 'Total']
# 30
# 3
# ['Yellow Cards', 'Pos', 'Name', 'Total', '1 ', 'J. Lerma', '8', '1 ', 'Jorginho', '8', '1 ', 'L. Milivojevic', '8', '4 ', 'R. Saïss', '7', '4 ', 'P. Billing', '7', '4 ', 'I. Gündogan', '7', '4 ', 'A. Westwood', '7', '4 ', 'L. Dunk', '7', '9 ', 'A. Cresswell', '6', '9 ', 'I. Diop', '6', 'More Stats']
# ['Pos', 'Name', 'Total']
# 30
# 3
# ['Red Cards', 'Pos', 'Name', 'Total', '1 ', 'C. Kabasele', '2', '1 ', 'H. Son', '2', '3 ', 'F. Andone', '1', '3 ', 'K. Danso', '1', '3 ', 'W. Boly', '1', '3 ', 'M. Sakho', '1', '3 ', 'S. Francis', '1', '3 ', 'A. Mariappa', '1', '3 ', 'A. Masuaku', '1', '3 ', 'M. Schneiderlin', '1', 'More Stats']
# ['Pos', 'Name', 'Total']
# 30
# 3
# ['Penalty Kick Goals', 'Pos', 'Name', 'Total', '1 ', 'M. Rashford', '5', '2 ', 'J. Vardy', '3', '3 ', 'T. Deeney', '2', '3 ', 'S. Agüero', '2', '3 ', 'J. Milner', '2', '3 ', 'M. Noble', '2', '3 ', 'M. Salah', '2', '3 ', 'Jorginho', '2', '3 ', 'H. Kane', '2', '3 ', 'L. Milivojevic', '2', 'More Stats']
# ['Pos', 'Name', 'Total']
# 30
# 3
# ['Red Cards', 'Pos', 'Name', 'Total', '1 ', 